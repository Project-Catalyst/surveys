# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# importing data
xls = pd.ExcelFile('Spanish - Private.xlsx')
df = pd.read_excel(xls, 'Respuestas de formulario 1')

# %%
column = '¿En cuáles fondos previos ha votado?'
l = list(df[column])
l = [i.split(', ') for i in l]
l2 = []
for i in l:
    for n in range(len(i)):
        l2.append(i[n])
l2 = pd.Series(l2)
s1 = l2.value_counts()
fig = plt.figure(figsize=(10, 6))
ax = s1.plot.bar()
plt.title(column, y=1.025, fontsize = 12)
plt.savefig('./charts/' + column[:-1] + '.jpeg', dpi=300, bbox_inches="tight")

# %%
column = 'How many proposals did you vote positive for?'
hue_column = 'Other than voting have you actively participated in Cardano Project Catalyst?'
def plot_hue(column, hue_column):
    fig = plt.figure(figsize=(10, 6))
    ax = sns.histplot(x = column, data = df.astype(str), hue = hue_column, multiple="stack", shrink=0.8)
    sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
    plt.xticks(rotation=90)
    plt.title(column, y=1.025, fontsize = 12)
    plt.savefig('./charts/' + column.replace('?','').replace('.','').replace('\"','').replace(':"','') + '.jpeg', dpi=300, bbox_inches="tight")
    plt.show()

# %%
def plot_column_value_counts(column):
    fig = plt.figure()
    df[column].value_counts().plot.bar()
    fig.suptitle(column)
    plt.savefig('./charts/' + column.replace('?','').replace('.','').replace('\"','') + '.jpeg', dpi=300, bbox_inches="tight")
    plt.show()

# %%
columns = ['Además de votar, ¿ha participado activamente en Cardano Project Catalyst?',
           'Por favor, indique su grupo de edad.',
           'Recientemente, se anunció el papel del dRep. ¿Ve valor en poder asignar su voto a un apoderado?',
           '¿Votó en el Fondo 7?',
           'Con relación a su voto del Fondo 7, ¿a cuántas propuestas votó positivo?',
           '¿Por cuántas propuestas votó negativo?',
           '¿Hay algo en una propuesta que conduzca a un voto negativo automáticamente?',
           '¿Cuánto tiempo dedicó a la consideración de su voto en cada propuesta?',
           '¿Tiene una cuenta de Ideascale?',
           'En relación con la votación del Fondo 6, ¿Leyó las propuestas que votó en Ideascale?',
           '¿Qué tan importante es para usted ser recompensado por votar?',
           'En su opinión, la cantidad de recompensa por votar es...',
           '¿Cuánto peso da a las puntuaciones de los asesores de la comunidad (CA)?',
           '¿Cuánto poder de voto controla? (Si desea responder y permanecer en el anonimato, puede optar por no proporcionar una dirección de correo electrónico).',
           '¿Con cuántas billeteras vota?',
           '¿Vota en nombre de otras personas?',
           'Si existiera una forma de obtener "boletas de expertos" y "consejos para el votante" que le orienten sobre sus propias opciones de voto, ¿los utilizaría?',
           'Con relación a la votación, ¿preferiría dedicar más o menos tiempo?',
           '¿Cómo calificaría su experiencia general con la votación en el Fondo 6 de Catalyst?',
           'Si ha participado en algún fondo anterior, ¿considera que el proceso general ha mejorado?',
           '¿Por cuántas propuestas votó en el desafío F7: Grow Latin America, Grow Cardano?',
           'En relación con Project Catalyst, indique si cree que los siguientes temas, son de gran importancia actualmente.',
           '¿Cómo calificaría la importancia de encuestas como esta?',
           '¿Cómo calificaría nuestra ejecución de esta encuesta?',
           '¿Qué probabilidades hay, que participe en una encuesta de votantes si no estuviera incentivada?']

for i in columns:
    plot_column_value_counts(i)

# %%
columns = ['Por favor, indique su grupo de edad.',
           'Recientemente, se anunció el papel del dRep. ¿Ve valor en poder asignar su voto a un apoderado?',
           '¿Votó en el Fondo 7?',
           'Con relación a su voto del Fondo 7, ¿a cuántas propuestas votó positivo?',
           '¿Por cuántas propuestas votó negativo?',
           '¿Hay algo en una propuesta que conduzca a un voto negativo automáticamente?',
           '¿Cuánto tiempo dedicó a la consideración de su voto en cada propuesta?',
           '¿Tiene una cuenta de Ideascale?',
           'En relación con la votación del Fondo 6, ¿Leyó las propuestas que votó en Ideascale?',
           '¿Qué tan importante es para usted ser recompensado por votar?',
           'En su opinión, la cantidad de recompensa por votar es...',
           '¿Cuánto peso da a las puntuaciones de los asesores de la comunidad (CA)?',
           '¿Cuánto poder de voto controla? (Si desea responder y permanecer en el anonimato, puede optar por no proporcionar una dirección de correo electrónico).',
           '¿Con cuántas billeteras vota?',
           '¿Vota en nombre de otras personas?',
           'Si existiera una forma de obtener "boletas de expertos" y "consejos para el votante" que le orienten sobre sus propias opciones de voto, ¿los utilizaría?',
           'Con relación a la votación, ¿preferiría dedicar más o menos tiempo?',
           '¿Cómo calificaría su experiencia general con la votación en el Fondo 6 de Catalyst?',
           'Si ha participado en algún fondo anterior, ¿considera que el proceso general ha mejorado?',
           '¿Por cuántas propuestas votó en el desafío F7: Grow Latin America, Grow Cardano?',
           'En relación con Project Catalyst, indique si cree que los siguientes temas, son de gran importancia actualmente.',
           '¿Cómo calificaría la importancia de encuestas como esta?',
           '¿Cómo calificaría nuestra ejecución de esta encuesta?',
           '¿Qué probabilidades hay, que participe en una encuesta de votantes si no estuviera incentivada?']

hue_column = 'Además de votar, ¿ha participado activamente en Cardano Project Catalyst?'

for i in columns:
    plot_hue(i, hue_column)

# %%
columns = ['Además de votar, ¿ha participado activamente en Cardano Project Catalyst?',
           'Por favor, indique su grupo de edad.',
           'Recientemente, se anunció el papel del dRep. ¿Ve valor en poder asignar su voto a un apoderado?',
           '¿Votó en el Fondo 7?',
           'Con relación a su voto del Fondo 7, ¿a cuántas propuestas votó positivo?',
           '¿Por cuántas propuestas votó negativo?',
           '¿Hay algo en una propuesta que conduzca a un voto negativo automáticamente?',
           '¿Cuánto tiempo dedicó a la consideración de su voto en cada propuesta?',
           '¿Tiene una cuenta de Ideascale?',
           'En relación con la votación del Fondo 6, ¿Leyó las propuestas que votó en Ideascale?',
           '¿Qué tan importante es para usted ser recompensado por votar?',
           'En su opinión, la cantidad de recompensa por votar es...',
           '¿Cuánto peso da a las puntuaciones de los asesores de la comunidad (CA)?',
           '¿Con cuántas billeteras vota?',
           '¿Vota en nombre de otras personas?',
           'Si existiera una forma de obtener "boletas de expertos" y "consejos para el votante" que le orienten sobre sus propias opciones de voto, ¿los utilizaría?',
           'Con relación a la votación, ¿preferiría dedicar más o menos tiempo?',
           '¿Cómo calificaría su experiencia general con la votación en el Fondo 6 de Catalyst?',
           'Si ha participado en algún fondo anterior, ¿considera que el proceso general ha mejorado?',
           '¿Por cuántas propuestas votó en el desafío F7: Grow Latin America, Grow Cardano?',
           'En relación con Project Catalyst, indique si cree que los siguientes temas, son de gran importancia actualmente.',
           '¿Cómo calificaría la importancia de encuestas como esta?',
           '¿Cómo calificaría nuestra ejecución de esta encuesta?',
           '¿Qué probabilidades hay, que participe en una encuesta de votantes si no estuviera incentivada?']

hue_column = '¿Cuánto poder de voto controla? (Si desea responder y permanecer en el anonimato, puede optar por no proporcionar una dirección de correo electrónico).'

for i in columns:
    plot_hue(i, hue_column)
